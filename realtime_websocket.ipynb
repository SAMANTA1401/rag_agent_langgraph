# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# http

# %% [markdown]
# frequent requests

# %% [markdown]
# unnecessary api calls

# %% [markdown]
# polling frequently

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# websocket

# %% [markdown]
# create pipeline

# %% [markdown]
# handshake established connection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# no need frequent polling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# webwooks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WEBHOOKS

# %% [markdown]
# save resources and reduces unnecessary api calls

# %% [markdown]
# by post request webhook url

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# through api
#
# but not able to get immediate responses

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# message queues

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
